# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings

warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
df = pd.read_csv(r"C:\Users\utkar\Desktop\ProjectX\ProjectX\Notebook\Telco_Customer_Churn.csv")

# %%
df.head(1500)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 1495  4472-VESGY  Female              0     Yes        Yes      52
# 1496  3195-TQDZX    Male              0      No         No       3
# 1497  3128-YOVTD  Female              0     Yes        Yes      51
# 1498  0529-ONKER    Male              1      No         No      15
# 1499  1728-CXQBE    Male              1     Yes         No      64
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 0              No  No phone service             DSL                   No  ...
# 1             Yes                No             DSL                  Yes  ...
# 2             Yes                No             DSL                  Yes  ...
# 3              No  No phone service             DSL                  Yes  ...
# 4             Yes                No     Fiber optic                   No  ...
# ...           ...               ...             ...                  ...  ...
# 1495          Yes               Yes     Fiber optic                  Yes  ...
# 1496          Yes                No              No  No internet service  ...
# 1497          Yes                No     Fiber optic                  Yes  ...
# 1498          Yes               Yes     Fiber optic                   No  ...
# 1499          Yes               Yes     Fiber optic                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 0                      No                   No                   No
# 1                     Yes                   No                   No
# 2                      No                   No                   No
# 3                     Yes                  Yes                   No
# 4                      No                   No                   No
# ...                   ...                  ...                  ...
# 1495                  Yes                   No                   No
# 1496  No internet service  No internet service  No internet service
# 1497                   No                   No                   No
# 1498                   No                   No                   No
# 1499                  Yes                   No                   No
#
#           StreamingMovies        Contract PaperlessBilling  \
# 0                      No  Month-to-month              Yes
# 1                      No        One year               No
# 2                      No  Month-to-month              Yes
# 3                      No        One year               No
# 4                      No  Month-to-month              Yes
# ...                   ...             ...              ...
# 1495                  Yes  Month-to-month               No
# 1496  No internet service  Month-to-month              Yes
# 1497                   No  Month-to-month              Yes
# 1498                   No  Month-to-month               No
# 1499                  Yes  Month-to-month              Yes
#
#                   PaymentMethod MonthlyCharges  TotalCharges Churn
# 0              Electronic check          29.85         29.85    No
# 1                  Mailed check          56.95        1889.5    No
# 2                  Mailed check          53.85        108.15   Yes
# 3     Bank transfer (automatic)          42.30       1840.75    No
# 4              Electronic check          70.70        151.65   Yes
# ...                         ...            ...           ...   ...
# 1495  Bank transfer (automatic)          98.15        4993.4    No
# 1496           Electronic check          20.25         61.45    No
# 1497  Bank transfer (automatic)          79.15       4018.55    No
# 1498           Electronic check          75.65       1146.65   Yes
# 1499           Electronic check          94.25        6081.4    No
#
# [1500 rows x 21 columns]
